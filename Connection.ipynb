# %%
import datajoint as dj

# %%
dj.config['database.host'] = 'db.data-science-ust.net'

# %%
dj.config['database.user'] = 'dimitri'

# %%
import getpass

# %%
dj.config['database.password'] = getpass.getpass()
# Out:
# ········

# %%
dj.conn()
# Out:
# Connecting dimitri@db.data-science-ust.net:3306
# DataJoint connection (connected) dimitri@db.data-science-ust.net:3306

# %%
dj.config.save_local()
